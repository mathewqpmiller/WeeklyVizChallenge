# %% [markdown]
# ### Weekly Viz Challenge: Ride Share Bubble Plot

# %%
# WeeklyVizChallenge file directory path
# /My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend

# %%
# Load Dependencies for this project

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Identify File Path

rural_df = pd.read_csv("/My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend/Data/rural_rideshare_data.csv")
suburban_df = pd.read_csv("/My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend/Data/suburban_rideshare_data.csv")
urban_df = pd.read_csv("/My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend/Data/urban_rideshare_data.csv")

# Verify their types
print(type(rural_df))    # Should output: <class 'pandas.core.frame.DataFrame'>
print(type(suburban_df)) # Should output: <class 'pandas.core.frame.DataFrame'>
print(type(urban_df))    # Should output: <class 'pandas.core.frame.DataFrame'>

rural_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#            City  Average Fare ($)  Total Number of Rides  \
# 0      New York             20.65                 131342
# 1   Los Angeles             23.82                  14625
# 2   San Antonio              8.19                  10678
# 3        Austin             18.77                  84606
# 4  Jacksonville             23.27                  84921
#
#    Total Number of Drivers City Type
# 0                      684     Rural
# 1                     3936     Rural
# 2                     2074     Rural
# 3                      630     Rural
# 4                     1132     Rural

# %%
# Test rural df to make sure it prints correctly.

suburban_df.head()
# Out:
#            City  Average Fare ($)  Total Number of Rides  \
# 0       Phoenix             17.98                  89193
# 1  Philadelphia             22.12                  12393
# 2        Dallas             18.52                  68657
# 3      San Jose             13.35                  11129
# 4    Fort Worth             19.10                 118673
#
#    Total Number of Drivers City Type
# 0                     2179  Suburban
# 1                     4230  Suburban
# 2                     3702  Suburban
# 3                     3390  Suburban
# 4                     1248  Suburban

# %%
urban_df.head()
# Out:
#          City  Average Fare ($)  Total Number of Rides  \
# 0     Chicago             24.80                 331621
# 1     Houston             16.10                 238172
# 2   San Diego             29.72                 365065
# 3     Seattle             36.29                 318489
# 4  Louisville             20.24                  96850
#
#    Total Number of Drivers City Type
# 0                     1081     Urban
# 1                     2600     Urban
# 2                     4588     Urban
# 3                     4678     Urban
# 4                     3441     Urban

# %%
# Merge all of the datasets together

processed_df = pd.concat([rural_df, suburban_df, urban_df], ignore_index=True)

# %%
print(processed_df.info())  # Check data types
print(processed_df.isnull().sum())  # Check for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   City                     119 non-null    object
#  1   Average Fare ($)         119 non-null    float64
#  2   Total Number of Rides    119 non-null    int64
#  3   Total Number of Drivers  119 non-null    int64
#  4   City Type                119 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.8+ KB
# None
# City                       0
# Average Fare ($)           0
# Total Number of Rides      0
# Total Number of Drivers    0
# City Type                  0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df, x="distance", y="price", size="num_riders",
    hue="service_type", sizes=(20, 400), alpha=0.5
)
plt.title("Rideshare Pricing by Distance and Service Type")
plt.xlabel("Distance (miles)")
plt.ylabel("Price ($)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 2>()
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.scatterplot(
#       3     data=df, x="distance", y="price", size="num_riders",
#       4     hue="service_type", sizes=(20, 400), alpha=0.5
#       5 )
#       6 plt.title("Rideshare Pricing by Distance and Service Type")
#       7 plt.xlabel("Distance (miles)")
#
# File c:\Users\Mathew\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
# Saved File
df.to_csv("/My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend/Cleaning/processed_df.csv", index=False)

# %%
# Saved Vizualization
plt.savefig("/My Drive/Data Analytics (Main Folder)/Projects & Work/Analytics-Projects/WeeklyVizChallenge (Ongoing Projects)/Project1_Rideshare_AverageFare_Trend/bbubble_plot.png")
